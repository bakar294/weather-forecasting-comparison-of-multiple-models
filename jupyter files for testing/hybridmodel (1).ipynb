# %%
#arima on cycle
import pandas as pd
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt

# Load the dataset
file_path = 'Daily atmospheric CO2 concentration.csv'
data = pd.read_csv(file_path)
data['date'] = pd.to_datetime(data[['year', 'month', 'day']])
data.set_index('date', inplace=True)
co2_trend = data['cycle']

# Split data into train and test sets
train_size = int(len(co2_trend) * 0.8)
train, test = co2_trend[:train_size], co2_trend[train_size:]

# Fit an ARIMA model (auto_arima can be used to find the best parameters)
arima_model = ARIMA(train, order=(1,1,1))
arima_result = arima_model.fit()

# Forecast using ARIMA
arima_forecast = arima_result.get_forecast(steps=len(test))
forecast_values = arima_forecast.predicted_mean

# Calculate residuals
residuals = test - forecast_values

# Normalize residuals for ANN training
scaler = MinMaxScaler()
residuals_scaled = scaler.fit_transform(residuals.values.reshape(-1, 1))

# Prepare input for ANN
X_ann = residuals_scaled[:-1]
y_ann = residuals_scaled[1:]

# Define and train the ANN model
ann_model = Sequential([
    Dense(10, activation='relu', input_shape=(1,)),
    Dense(1)
])
ann_model.compile(optimizer='adam', loss='mean_squared_error')
ann_model.fit(X_ann, y_ann, epochs=50, batch_size=1, verbose=1)

# Predict corrections using the ANN model
ann_predictions = ann_model.predict(X_ann)

# Apply corrections
corrected_forecasts = forecast_values[:-1] + scaler.inverse_transform(ann_predictions).flatten()

# Calculate final MSE and RMSE
mse = mean_squared_error(test[1:], corrected_forecasts)
rmse = np.sqrt(mse)

print(f'Final MSE: {mse:.4f}')
print(f'Final RMSE: {rmse:.4f}')

# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(test.index, test, label='Actual CO2 Trend', color='blue')
plt.plot(test.index[1:], corrected_forecasts, label='Corrected Forecasts', color='red', linestyle='--')
plt.title('ARIMA + ANN Corrected Forecasts')
plt.xlabel('Date')
plt.ylabel('CO2 Cycle')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Epoch 1/50
# 731/731 [==============================] - 3s 3ms/step - loss: 0.0473
# Epoch 2/50
# 731/731 [==============================] - 2s 3ms/step - loss: 0.0072
# Epoch 3/50
# 731/731 [==============================] - 1s 2ms/step - loss: 9.0582e-04
# Epoch 4/50
# 731/731 [==============================] - 2s 2ms/step - loss: 5.5506e-05
# Epoch 5/50
# 731/731 [==============================] - 1s 2ms/step - loss: 3.0745e-05
# Epoch 6/50
# 731/731 [==============================] - 1s 2ms/step - loss: 2.7985e-05
# Epoch 7/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.6030e-05
# Epoch 8/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.4788e-05
# Epoch 9/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.6515e-05
# Epoch 10/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.6619e-05
# Epoch 11/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.6244e-05
# Epoch 12/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.9021e-05
# Epoch 13/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.8964e-05
# Epoch 14/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.8094e-05
# Epoch 15/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.8973e-05
# Epoch 16/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.8175e-05
# Epoch 17/50
# 731/731 [==============================] - 1s 2ms/step - loss: 2.9911e-05
# Epoch 18/50
# 731/731 [==============================] - 1s 2ms/step - loss: 2.8803e-05
# Epoch 19/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.9672e-05
# Epoch 20/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.6869e-05
# Epoch 21/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.9651e-05
# Epoch 22/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.7408e-05
# Epoch 23/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.9694e-05
# Epoch 24/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.8950e-05
# Epoch 25/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.7299e-05
# Epoch 26/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.8481e-05
# Epoch 27/50
# 731/731 [==============================] - 1s 1ms/step - loss: 3.0658e-05
# Epoch 28/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.6950e-05
# Epoch 29/50
# 731/731 [==============================] - 1s 2ms/step - loss: 3.0339e-05
# Epoch 30/50
# 731/731 [==============================] - 1s 2ms/step - loss: 3.1623e-05
# Epoch 31/50
# 731/731 [==============================] - 1s 2ms/step - loss: 2.8976e-05
# Epoch 32/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.9999e-05
# Epoch 33/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.7310e-05
# Epoch 34/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.9545e-05
# Epoch 35/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.7875e-05
# Epoch 36/50
# 731/731 [==============================] - 1s 1ms/step - loss: 3.0813e-05
# Epoch 37/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.9817e-05
# Epoch 38/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.9361e-05
# Epoch 39/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.8460e-05
# Epoch 40/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.9655e-05
# Epoch 41/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.8490e-05
# Epoch 42/50
# 731/731 [==============================] - 1s 2ms/step - loss: 2.7847e-05
# Epoch 43/50
# 731/731 [==============================] - 1s 2ms/step - loss: 2.7773e-05
# Epoch 44/50
# 731/731 [==============================] - 1s 2ms/step - loss: 2.9214e-05
# Epoch 45/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.8680e-05
# Epoch 46/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.8800e-05
# Epoch 47/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.7765e-05
# Epoch 48/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.7389e-05
# Epoch 49/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.8484e-05
# Epoch 50/50
# 731/731 [==============================] - 1s 1ms/step - loss: 2.9795e-05
# 23/23 [==============================] - 0s 2ms/step
# Final MSE: 0.0021
# Final RMSE: 0.0458

# %%
#on trend column arima
import pandas as pd
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt

# Load the dataset
file_path = 'Daily atmospheric CO2 concentration.csv'
data = pd.read_csv(file_path)
data['date'] = pd.to_datetime(data[['year', 'month', 'day']])
data.set_index('date', inplace=True)
co2_trend = data['trend']

# Split data into train and test sets
train_size = int(len(co2_trend) * 0.8)
train, test = co2_trend[:train_size], co2_trend[train_size:]

# Fit an ARIMA model (auto_arima can be used to find the best parameters)
arima_model = ARIMA(train, order=(1,1,1))
arima_result = arima_model.fit()

# Forecast using ARIMA
arima_forecast = arima_result.get_forecast(steps=len(test))
forecast_values = arima_forecast.predicted_mean

# Calculate residuals
residuals = test - forecast_values

# Normalize residuals for ANN training
scaler = MinMaxScaler()
residuals_scaled = scaler.fit_transform(residuals.values.reshape(-1, 1))

# Prepare input for ANN
X_ann = residuals_scaled[:-1]
y_ann = residuals_scaled[1:]

# Define and train the ANN model
ann_model = Sequential([
    Dense(10, activation='relu', input_shape=(1,)),
    Dense(1)
])
ann_model.compile(optimizer='adam', loss='mean_squared_error')
ann_model.fit(X_ann, y_ann, epochs=50, batch_size=1, verbose=1)

# Predict corrections using the ANN model
ann_predictions = ann_model.predict(X_ann)

# Apply corrections
corrected_forecasts = forecast_values[:-1] + scaler.inverse_transform(ann_predictions).flatten()

# Calculate final MSE and RMSE
mse = mean_squared_error(test[1:], corrected_forecasts)
rmse = np.sqrt(mse)

print(f'Final MSE: {mse:.4f}')
print(f'Final RMSE: {rmse:.4f}')

# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(test.index, test, label='Actual CO2 Trend', color='blue')
plt.plot(test.index[1:], corrected_forecasts, label='Corrected Forecasts', color='red', linestyle='--')
plt.title('ARIMA + ANN Corrected Forecasts')
plt.xlabel('Date')
plt.ylabel('CO2 trend')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Epoch 1/50
# 731/731 [==============================] - 1s 1ms/step - loss: 0.0219
# Epoch 2/50
# 731/731 [==============================] - 1s 1ms/step - loss: 1.8684e-04
# Epoch 3/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.6744e-05
# Epoch 4/50
# 731/731 [==============================] - 1s 1ms/step - loss: 3.6582e-05
# Epoch 5/50
# 731/731 [==============================] - 1s 1ms/step - loss: 3.5723e-05
# Epoch 6/50
# 731/731 [==============================] - 1s 1ms/step - loss: 3.3397e-05
# Epoch 7/50
# 731/731 [==============================] - 1s 1ms/step - loss: 3.6350e-05
# Epoch 8/50
# 731/731 [==============================] - 2s 3ms/step - loss: 3.8527e-05
# Epoch 9/50
# 731/731 [==============================] - 1s 2ms/step - loss: 4.2275e-05
# Epoch 10/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.6614e-05
# Epoch 11/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.5220e-05
# Epoch 12/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.8367e-05
# Epoch 13/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.9945e-05
# Epoch 14/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.7683e-05
# Epoch 15/50
# 731/731 [==============================] - 1s 2ms/step - loss: 4.4827e-05
# Epoch 16/50
# 731/731 [==============================] - 3s 5ms/step - loss: 5.1282e-05
# Epoch 17/50
# 731/731 [==============================] - 3s 4ms/step - loss: 4.5329e-05
# Epoch 18/50
# 731/731 [==============================] - 2s 3ms/step - loss: 4.9201e-05
# Epoch 19/50
# 731/731 [==============================] - 2s 2ms/step - loss: 4.5875e-05
# Epoch 20/50
# 731/731 [==============================] - 3s 4ms/step - loss: 4.8696e-05
# Epoch 21/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.3972e-05
# Epoch 22/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.5038e-05
# Epoch 23/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.5170e-05
# Epoch 24/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.6762e-05
# Epoch 25/50
# 731/731 [==============================] - 1s 2ms/step - loss: 4.6588e-05
# Epoch 26/50
# 731/731 [==============================] - 1s 2ms/step - loss: 4.4287e-05
# Epoch 27/50
# 731/731 [==============================] - 1s 2ms/step - loss: 4.3641e-05
# Epoch 28/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.4205e-05
# Epoch 29/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.2746e-05
# Epoch 30/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.7953e-05
# Epoch 31/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.3608e-05
# Epoch 32/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.4320e-05
# Epoch 33/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.9040e-05
# Epoch 34/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.2748e-05
# Epoch 35/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.4978e-05
# Epoch 36/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.5845e-05
# Epoch 37/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.7193e-05
# Epoch 38/50
# 731/731 [==============================] - 1s 2ms/step - loss: 4.0967e-05
# Epoch 39/50
# 731/731 [==============================] - 1s 2ms/step - loss: 4.3347e-05
# Epoch 40/50
# 731/731 [==============================] - 1s 2ms/step - loss: 4.0265e-05
# Epoch 41/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.7385e-05
# Epoch 42/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.1899e-05
# Epoch 43/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.4087e-05
# Epoch 44/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.3684e-05
# Epoch 45/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.3035e-05
# Epoch 46/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.1030e-05
# Epoch 47/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.1172e-05
# Epoch 48/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.4655e-05
# Epoch 49/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.5872e-05
# Epoch 50/50
# 731/731 [==============================] - 1s 1ms/step - loss: 4.0417e-05
# 23/23 [==============================] - 0s 1ms/step
# Final MSE: 0.0001
# Final RMSE: 0.0071

# %%
import numpy as np

# Assuming 'test' contains the actual values and 'corrected_forecasts' contains the predictions
# These variables need to be aligned in length and indexing

# Calculate MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Assuming 'test' and 'corrected_forecasts' are correctly aligned and of the same length
actual_values = test[1:]  # Adjust slicing if necessary to align with 'corrected_forecasts'
predicted_values = corrected_forecasts

mape = mean_absolute_percentage_error(actual_values, predicted_values)
accuracy = 100 - mape

print(f"MAPE: {mape:.2f}%")
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# MAPE: 0.00%
# Accuracy: 100.00%

# %%
#crossvalidation check

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.arima.model import ARIMA
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
# Load dataset
data = pd.read_csv('Daily atmospheric CO2 concentration.csv')
data['date'] = pd.to_datetime(data[['year', 'month', 'day']])
data.set_index('date', inplace=True)

# Choose a column to model, e.g., 'trend' or 'cycle'
column_to_model = 'trend'
time_series = data[column_to_model]
tscv = TimeSeriesSplit(n_splits=5)
# Prepare to collect scores
mse_scores = []

for train_index, test_index in tscv.split(time_series):
    train, test = time_series.iloc[train_index], time_series.iloc[test_index]

    # Fit ARIMA model
    arima_model = ARIMA(train, order=(1,1,1))
    arima_result = arima_model.fit()
    arima_forecast = arima_result.forecast(steps=len(test))

    # Compute residuals
    residuals = test - arima_forecast

    # Normalize residuals for ANN training
    scaler = MinMaxScaler()
    residuals_scaled = scaler.fit_transform(residuals.values.reshape(-1, 1))
    X_ann = residuals_scaled[:-1]
    y_ann = residuals_scaled[1:]

    # Define and train the ANN model
    ann_model = Sequential([
        Dense(10, activation='relu', input_shape=(1,)),
        Dense(1)
    ])
    ann_model.compile(optimizer='adam', loss='mean_squared_error')
    ann_model.fit(X_ann, y_ann, epochs=50, batch_size=1, verbose=0)  # verbose=0 for no output

    # Predict corrections using the ANN model
    ann_predictions = ann_model.predict(X_ann)

    # Apply corrections
    corrected_forecasts = arima_forecast[:-1] + scaler.inverse_transform(ann_predictions).flatten()

    # Calculate and store MSE for this fold
    mse = mean_squared_error(test[1:], corrected_forecasts)  # ensure lengths align
    mse_scores.append(mse)

# Output the average MSE over all folds
average_mse = np.mean(mse_scores)
print(f'Average MSE across all folds: {average_mse:.4f}')
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# 19/19 [==============================] - 0s 1ms/step
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# 19/19 [==============================] - 0s 1ms/step
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 19/19 [==============================] - 0s 1ms/step
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 19/19 [==============================] - 0s 1ms/step
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 19/19 [==============================] - 0s 1ms/step
# Average MSE across all folds: 0.0001
